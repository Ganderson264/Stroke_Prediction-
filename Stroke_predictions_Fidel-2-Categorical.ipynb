# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import mean_squared_error, r2_score, balanced_accuracy_score
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
import os

# %% [markdown]
# ### Load Clean DataSet

# %%
df=pd.read_csv('clean-healthcare-categorical-dataset-stroke-data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4908 entries, 0 to 4907
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   age                4908 non-null   float64
#  1   hypertension       4908 non-null   int64
#  2   heart_disease      4908 non-null   int64
#  3   ever_married       4908 non-null   int64
#  4   work_type          4908 non-null   int64
#  5   avg_glucose_level  4908 non-null   float64
#  6   bmi                4908 non-null   float64
#  7   smoking_status     4908 non-null   int64
#  8   Male               4908 non-null   int64
#  9   Urban              4908 non-null   int64
#  10  stroke             4908 non-null   int64
# dtypes: float64(3), int64(8)
# memory usage: 421.9 KB

# %% [markdown]
# ## About the DataSet
#
# ### **EXTREMELY UNBALANCED**
#
# ### The "cleaned and encoded" dataset contains 4908 records
# ### Only 209 (4.25%) of these are positive for stroke and the rest (95.74%) are negative
#
# ### Will try to create models with different less unbalanced samples to run prediction models
#
# ### **Fortunately/Unfortunately there might not be enough positive cases to effectively predict**

# %% [markdown]
# ### Training Models

# %%
models={}
models['Logistic Regression']=LogisticRegression()
models['Random Forest Clasifier']=RandomForestClassifier()
models['SVC']=SVC()

# %% [markdown]
# ### Re-Assign and int value to the Scaled result

# %% [markdown]
# ### DataFrame Dictionary with Proportional Positive and negative Samples

# %%
def create_sample_dfs_dictionary(df):
    Positives=df.loc[df['stroke']==df['stroke'].max()]
    Negative_sample_1=df.loc[df['stroke']==df['stroke'].min()] \
        .sample(len(Positives),random_state=1, ignore_index=True)
    Negative_sample_2=df.loc[df['stroke']==df['stroke'].min()] \
        .sample(len(Positives),random_state=3, ignore_index=True)
    Negative_sample_3=df.loc[df['stroke']==df['stroke'].min()] \
        .sample(len(Positives),random_state=5, ignore_index=True)
    DataFrames={}
    DataFrames['One to One']= pd.concat([Positives,Negative_sample_1], axis=0)
    DataFrames['One to Two']= pd.concat([Positives,Negative_sample_1, \
                                        Negative_sample_2], axis=0)
    DataFrames['One to Three']= pd.concat([Positives,Negative_sample_1, \
                                        Negative_sample_2,Negative_sample_3], axis=0)
    return DataFrames

# %% [markdown]
# ### Print Explained Confusion Matrix

# %%
def print_confusion_matrix(y_test,prediction,Labels):
    cm=confusion_matrix(y_test,prediction,labels=Labels)
    print(f'\033[1mConfusion Matrix\033[0m')
    print(f'Predicted\\Actual\tPositive\tNegative')
    print(f'Positive({cm[0][0]+cm[0][1]})\t\t{cm[0][0]}\t\t{cm[0][1]}')
    print(f'Negative({cm[1][0]+cm[1][1]})\t\t{cm[1][0]}\t\t{cm[1][1]}')

# %% [markdown]
# ### RandomForestClassifier best depth calculator

# %%
def best_depth(X_train,X_test,y_train,y_test):
    # print('Calculating best depth for RandomForestClassifier')
    train_score=0
    depth=0
    best=0
    hight_score=0
    while train_score<1:
        depth+=1
        clf = RandomForestClassifier(max_depth = depth)
        clf.fit(X_train, y_train)
        train_score = clf.score(X_train,y_train)
        test_score = clf.score(X_test,y_test)
        score=test_score*(1-(train_score-test_score))
        if hight_score<score:
            hight_score=score
            best=depth
    return best

# %% [markdown]
# ### Create/Update afile with th results

# %%
def append_results(df):
    if os.path.isfile('fidel-test-results-LabelEncoded.csv'):
        df.to_csv('fidel-test-results-LabelEncoded.csv', mode='a',index=False, header=False )
    else:
        df.to_csv('fidel-test-results-LabelEncoded.csv', mode='w',index=False )

# %% [markdown]
# ### **train_test_split and ALL the tests**

# %%
def Test_Results(df,compression):
    
    
    model_results={'Test_Model':[], 'Proportion':[], 'Compression':[], 'Model_Score':[],\
                   'Balanced Accuracy':[], 'Precision':[],'Recall':[],'f1-score':[]}
    X_available=df.copy().drop(columns='stroke')
    y_available=df['stroke']
    tab='   '
    DataFrames=create_sample_dfs_dictionary(df)
    for name, Learning_model in models.items():    
        print(f'\033[94m\033[1m{name}\033[0m')
        for key,df in DataFrames.items():
            X=df.copy().drop(columns='stroke')
            y=df['stroke']
            X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=1)
            if name=='Random Forest Clasifier':
                Depth=best_depth(X_train,X_test,y_train,y_test)
                Learning_model=RandomForestClassifier(max_depth=Depth)
            model=Learning_model
            model.fit(X_train,y_train)
            predicted = model.predict(X_test)
            available_predict=model.predict(X_available)

            # Score the predictions with mse and r2
            test_balanced_accuracy=balanced_accuracy_score(y_test, predicted)
            available_balanced_accuracy=balanced_accuracy_score(y_available, available_predict)
            tcr=classification_report(y_test, predicted, labels=[1,0],output_dict=True)
            acr=classification_report(y_available, available_predict,
                                      labels=[1,0],output_dict=True)
            #region Print Results
            if name=='Random Forest Clasifier':
                print(f'{tab}\033[96m\033[1m{key} ({len(df)} items, depth of {Depth})\033[0m : ', end='')
            else:
                print(f'{tab}\033[96m\033[1m{key} ({len(df)} items)\033[0m : ', end='')
            print(f'Model Score: {model.score(X_train,y_train):.4f}')
            print(f'\t\t\t\t\t\033[1mTest Data\tAvailable Data\t\tDifference\033[0m')
            print(f"{tab}{tab}Balanced Accuracy:\t\t{test_balanced_accuracy:.4f}"+
                f"\t\t\t{available_balanced_accuracy:.4f}\t\t"+
                f"{abs(test_balanced_accuracy-available_balanced_accuracy):.4f}")
            print(f"{tab}{tab}\033[1mNegative(0) results metrics\033[0m")
            print(f"{tab}{tab}{tab}Precision\t\t\t{tcr['0']['precision']:.4f}\t\t\t"+
                  f"{acr['0']['precision']:.4f}\t\t"+
                  f"{(tcr['0']['precision']-acr['0']['precision']):.4f}")
            print(f"{tab}{tab}{tab}Recall\t\t\t\t{tcr['0']['recall']:.4f}\t\t\t"+
                  f"{acr['0']['recall']:.4f}\t\t"+
                  f"{(tcr['0']['recall']-acr['0']['recall']):.4f}")
            print(f"{tab}{tab}{tab}f1-score(confidence)\t\t{tcr['0']['f1-score']:.4f}\t\t\t"+
                  f"{acr['0']['f1-score']:.4f}\t\t"+
                  f"{(tcr['0']['f1-score']-acr['0']['f1-score']):.4f}")
            print(f"{tab}{tab}\033[1mPositive(1) results metrics\033[0m")
            print(f"{tab}{tab}{tab}Precision\t\t\t{tcr['1']['precision']:.4f}\t\t\t"+
                  f"{acr['1']['precision']:.4f}\t\t"+
                  f"{(tcr['1']['precision']-acr['1']['precision']):.4f}")
            print(f"{tab}{tab}{tab}Recall\t\t\t\t{tcr['1']['recall']:.4f}\t\t\t"+
                  f"{acr['1']['recall']:.4f}\t\t"+
                  f"{(tcr['1']['recall']-acr['1']['recall']):.4f}")
            print(f"{tab}{tab}{tab}f1-score(confidence)\t\t{tcr['1']['f1-score']:.4f}\t\t\t"+
                  f"\033[33m\033[1m{acr['1']['f1-score']:.4f}\033[0m\t\t"+
                  f"{(tcr['1']['f1-score']-acr['1']['f1-score']):.4f}")
            print()
            #endregion

            model_results['Test_Model'].append(name)
            model_results['Proportion'].append(key)
            model_results['Compression'].append(compression)
            model_results['Model_Score'].append(model.score(X_train,y_train))
            model_results['Balanced Accuracy'].append(available_balanced_accuracy)
            model_results['Precision'].append(acr['1']['precision'])
            model_results['Recall'].append(acr['1']['recall'])
            model_results['f1-score'].append(acr['1']['f1-score'])
        print('***'*10)
    model_results_df=pd.DataFrame(model_results)
    append_results(model_results_df)

# %% [markdown]
# ### StandardScaler Scaled

# %%
ss=StandardScaler()
ss_scaled=ss.fit_transform(df)
ss_df=pd.DataFrame(ss_scaled, columns=df.columns)
ss_df
# Out:
#            age  hypertension  heart_disease  ever_married  work_type  \
# 0     1.069938     -0.318102       4.381499      0.729270  -0.155713
# 1     1.646336     -0.318102       4.381499      0.729270  -0.155713
# 2     0.271847     -0.318102      -0.228232      0.729270  -0.155713
# 3     1.601998      3.143642      -0.228232      0.729270   0.759543
# 4     1.690675     -0.318102      -0.228232      0.729270  -0.155713
# ...        ...           ...            ...           ...        ...
# 4903 -1.324334     -0.318102      -0.228232     -1.371234   1.674800
# 4904  1.690675     -0.318102      -0.228232      0.729270   0.759543
# 4905 -0.348890     -0.318102      -0.228232      0.729270   0.759543
# 4906  0.360524     -0.318102      -0.228232      0.729270  -0.155713
# 4907  0.050155     -0.318102      -0.228232      0.729270  -1.986225
#
#       avg_glucose_level       bmi  smoking_status      Male     Urban  \
# 0              2.777797  0.981145       -0.351828  1.200240  0.985436
# 1              0.014016  0.459086        0.585108  1.200240 -1.014779
# 2              1.484266  0.701016        1.522044 -0.833166  0.985436
# 3              1.549325 -0.623231        0.585108 -0.833166 -1.014779
# 4              1.821493  0.013426       -0.351828  1.200240  0.985436
# ...                 ...       ...             ...       ...       ...
# 4903          -0.049918 -1.310821       -1.288764 -0.833166 -1.014779
# 4904           0.448045  1.414072        0.585108 -0.833166  0.985436
# 4905          -0.502181  0.217156        0.585108 -0.833166 -1.014779
# 4906           1.373057 -0.419501       -0.351828  1.200240 -1.014779
# 4907          -0.450629 -0.343102       -1.288764 -0.833166  0.985436
#
#         stroke
# 0     4.741651
# 1     4.741651
# 2     4.741651
# 3     4.741651
# 4     4.741651
# ...        ...
# 4903 -0.210897
# 4904 -0.210897
# 4905 -0.210897
# 4906 -0.210897
# 4907 -0.210897
#
# [4908 rows x 11 columns]

# %% [markdown]
# ### Re-assign 1 and 0 to the value results

# %%
ss_df['stroke']=ss_df['stroke'].apply(lambda x: 1 if x>0 else 0)
ss_df['stroke'].value_counts()
# Out:
# stroke
# 0    4699
# 1     209
# Name: count, dtype: int64

# %%
for i in range(1,11):Test_Results(ss_df,'StandardScaler')
# Out:
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7572
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7894			0.7459		0.0435
#       Negative(0) results metrics
#          Precision			0.9268			0.9940		-0.0672
#          Recall				0.6441			0.5684		0.0756
#          f1-score(confidence)		0.7600			0.7233		0.0367
#       Positive(1) results metrics
#          Precision			0.6719			0.0869		0.5850
#          Recall				0.9348			0.9234		0.0113
#          f1-score(confidence)		0.7818			0.1588		0.6230
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8213
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7454			0.7483		0.0030
#       Negative(0) results metrics
#          Precision			0.8091			0.9814		-0.1723
#          Recall				0.8725			0.8651		0.0075
#          f1-score(confidence)		0.8396			0.9196		-0.0800
#       Positive(1) results metrics
#          Precision			0.7234			0.1723		0.5511
#          Recall				0.6182			0.6316		-0.0134
#          f1-score(confidence)		0.6667			0.2708		0.3959
#
#    One to Three (836 items, depth of 3) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5822			0.6016		0.0194
#       Negative(0) results metrics
#          Precision			0.7887			0.9660		-0.1773
#          Recall				0.9684			0.9736		-0.0053
#          f1-score(confidence)		0.8693			0.9698		-0.1005
#       Positive(1) results metrics
#          Precision			0.6667			0.2791		0.3876
#          Recall				0.1961			0.2297		-0.0336
#          f1-score(confidence)		0.3030			0.2520		0.0511
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7604
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7810			0.7450		0.0359
#       Negative(0) results metrics
#          Precision			0.9250			0.9950		-0.0700
#          Recall				0.6271			0.5522		0.0749
#          f1-score(confidence)		0.7475			0.7103		0.0372
#       Positive(1) results metrics
#          Precision			0.6615			0.0852		0.5763
#          Recall				0.9348			0.9378		-0.0030
#          f1-score(confidence)		0.7748			0.1562		0.6185
#
#    One to Two (627 items, depth of 5) : Model Score: 0.8532
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7363			0.7611		0.0248
#       Negative(0) results metrics
#          Precision			0.8018			0.9825		-0.1807
#          Recall				0.8725			0.8715		0.0011
#          f1-score(confidence)		0.8357			0.9236		-0.0880
#       Positive(1) results metrics
#          Precision			0.7174			0.1838		0.5336
#          Recall				0.6000			0.6507		-0.0507
#          f1-score(confidence)		0.6535			0.2866		0.3668
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8373
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6935			0.6946		0.0011
#       Negative(0) results metrics
#          Precision			0.8389			0.9745		-0.1356
#          Recall				0.9557			0.9442		0.0115
#          f1-score(confidence)		0.8935			0.9591		-0.0657
#       Positive(1) results metrics
#          Precision			0.7586			0.2620		0.4966
#          Recall				0.4314			0.4450		-0.0136
#          f1-score(confidence)		0.5500			0.3298		0.2202
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 3) : Model Score: 0.7859
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7894			0.7642		0.0252
#       Negative(0) results metrics
#          Precision			0.9268			0.9944		-0.0676
#          Recall				0.6441			0.6050		0.0390
#          f1-score(confidence)		0.7600			0.7523		0.0077
#       Positive(1) results metrics
#          Precision			0.6719			0.0942		0.5777
#          Recall				0.9348			0.9234		0.0113
#          f1-score(confidence)		0.7818			0.1709		0.6109
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8298
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7328			0.7438		0.0110
#       Negative(0) results metrics
#          Precision			0.7931			0.9804		-0.1873
#          Recall				0.9020			0.8847		0.0173
#          f1-score(confidence)		0.8440			0.9301		-0.0860
#       Positive(1) results metrics
#          Precision			0.7561			0.1886		0.5675
#          Recall				0.5636			0.6029		-0.0392
#          f1-score(confidence)		0.6458			0.2873		0.3585
#
#    One to Three (836 items, depth of 3) : Model Score: 0.7990
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6050			0.6175		0.0125
#       Negative(0) results metrics
#          Precision			0.7979			0.9674		-0.1695
#          Recall				0.9747			0.9719		0.0028
#          f1-score(confidence)		0.8775			0.9696		-0.0921
#       Positive(1) results metrics
#          Precision			0.7500			0.2941		0.4559
#          Recall				0.2353			0.2632		-0.0279
#          f1-score(confidence)		0.3582			0.2778		0.0804
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7572
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7810			0.7444		0.0366
#       Negative(0) results metrics
#          Precision			0.9250			0.9937		-0.0687
#          Recall				0.6271			0.5701		0.0570
#          f1-score(confidence)		0.7475			0.7245		0.0229
#       Positive(1) results metrics
#          Precision			0.6615			0.0868		0.5747
#          Recall				0.9348			0.9187		0.0161
#          f1-score(confidence)		0.7748			0.1586		0.6162
#
#    One to Two (627 items, depth of 5) : Model Score: 0.8681
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7363			0.7783		0.0420
#       Negative(0) results metrics
#          Precision			0.8018			0.9846		-0.1828
#          Recall				0.8725			0.8581		0.0145
#          f1-score(confidence)		0.8357			0.9170		-0.0813
#       Positive(1) results metrics
#          Precision			0.7174			0.1796		0.5378
#          Recall				0.6000			0.6986		-0.0986
#          f1-score(confidence)		0.6535			0.2857		0.3678
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8341
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6641			0.6858		0.0217
#       Negative(0) results metrics
#          Precision			0.8251			0.9737		-0.1486
#          Recall				0.9557			0.9457		0.0100
#          f1-score(confidence)		0.8856			0.9595		-0.0739
#       Positive(1) results metrics
#          Precision			0.7308			0.2587		0.4720
#          Recall				0.3725			0.4258		-0.0533
#          f1-score(confidence)		0.4935			0.3219		0.1716
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 1) : Model Score: 0.7572
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7894			0.7445		0.0449
#       Negative(0) results metrics
#          Precision			0.9268			0.9950		-0.0682
#          Recall				0.6441			0.5512		0.0929
#          f1-score(confidence)		0.7600			0.7094		0.0506
#       Positive(1) results metrics
#          Precision			0.6719			0.0850		0.5868
#          Recall				0.9348			0.9378		-0.0030
#          f1-score(confidence)		0.7818			0.1559		0.6259
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7412			0.7556		0.0144
#       Negative(0) results metrics
#          Precision			0.8036			0.9817		-0.1781
#          Recall				0.8824			0.8795		0.0028
#          f1-score(confidence)		0.8411			0.9278		-0.0867
#       Positive(1) results metrics
#          Precision			0.7333			0.1891		0.5442
#          Recall				0.6000			0.6316		-0.0316
#          f1-score(confidence)		0.6600			0.2911		0.3689
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8357
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6414			0.6809		0.0396
#       Negative(0) results metrics
#          Precision			0.8152			0.9734		-0.1581
#          Recall				0.9494			0.9408		0.0085
#          f1-score(confidence)		0.8772			0.9568		-0.0796
#       Positive(1) results metrics
#          Precision			0.6800			0.2404		0.4396
#          Recall				0.3333			0.4211		-0.0877
#          f1-score(confidence)		0.4474			0.3061		0.1413
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7540
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7870			0.7511		0.0359
#       Negative(0) results metrics
#          Precision			0.9070			0.9932		-0.0863
#          Recall				0.6610			0.5931		0.0679
#          f1-score(confidence)		0.7647			0.7427		0.0220
#       Positive(1) results metrics
#          Precision			0.6774			0.0904		0.5870
#          Recall				0.9130			0.9091		0.0040
#          f1-score(confidence)		0.7778			0.1644		0.6133
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8277
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7181			0.7457		0.0276
#       Negative(0) results metrics
#          Precision			0.7876			0.9808		-0.1932
#          Recall				0.8725			0.8789		-0.0064
#          f1-score(confidence)		0.8279			0.9270		-0.0991
#       Positive(1) results metrics
#          Precision			0.7045			0.1836		0.5209
#          Recall				0.5636			0.6124		-0.0488
#          f1-score(confidence)		0.6263			0.2826		0.3437
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8293
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6610			0.6724		0.0114
#       Negative(0) results metrics
#          Precision			0.8242			0.9725		-0.1483
#          Recall				0.9494			0.9476		0.0017
#          f1-score(confidence)		0.8824			0.9599		-0.0776
#       Positive(1) results metrics
#          Precision			0.7037			0.2523		0.4514
#          Recall				0.3725			0.3971		-0.0246
#          f1-score(confidence)		0.4872			0.3086		0.1786
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 4) : Model Score: 0.8147
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7732		0.0199
#       Negative(0) results metrics
#          Precision			0.8913			0.9931		-0.1018
#          Recall				0.6949			0.6469		0.0480
#          f1-score(confidence)		0.7810			0.7835		-0.0026
#       Positive(1) results metrics
#          Precision			0.6949			0.1018		0.5931
#          Recall				0.8913			0.8995		-0.0082
#          f1-score(confidence)		0.7810			0.1829		0.5981
#
#    One to Two (627 items, depth of 3) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7181			0.7487		0.0306
#       Negative(0) results metrics
#          Precision			0.7876			0.9813		-0.1937
#          Recall				0.8725			0.8706		0.0019
#          f1-score(confidence)		0.8279			0.9226		-0.0947
#       Positive(1) results metrics
#          Precision			0.7045			0.1773		0.5273
#          Recall				0.5636			0.6268		-0.0632
#          f1-score(confidence)		0.6263			0.2764		0.3499
#
#    One to Three (836 items, depth of 6) : Model Score: 0.8995
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7005			0.7580		0.0575
#       Negative(0) results metrics
#          Precision			0.8448			0.9806		-0.1358
#          Recall				0.9304			0.9274		0.0029
#          f1-score(confidence)		0.8855			0.9533		-0.0678
#       Positive(1) results metrics
#          Precision			0.6857			0.2651		0.4206
#          Recall				0.4706			0.5885		-0.1179
#          f1-score(confidence)		0.5581			0.3655		0.1926
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 3) : Model Score: 0.7827
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7918			0.7629		0.0289
#       Negative(0) results metrics
#          Precision			0.9487			0.9956		-0.0469
#          Recall				0.6271			0.5833		0.0438
#          f1-score(confidence)		0.7551			0.7356		0.0195
#       Positive(1) results metrics
#          Precision			0.6667			0.0914		0.5753
#          Recall				0.9565			0.9426		0.0139
#          f1-score(confidence)		0.7857			0.1667		0.6190
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8213
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7314			0.7478		0.0164
#       Negative(0) results metrics
#          Precision			0.8000			0.9811		-0.1811
#          Recall				0.8627			0.8736		-0.0108
#          f1-score(confidence)		0.8302			0.9242		-0.0940
#       Positive(1) results metrics
#          Precision			0.7021			0.1796		0.5226
#          Recall				0.6000			0.6220		-0.0220
#          f1-score(confidence)		0.6471			0.2787		0.3684
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8357
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6869			0.6925		0.0056
#       Negative(0) results metrics
#          Precision			0.8352			0.9743		-0.1392
#          Recall				0.9620			0.9449		0.0171
#          f1-score(confidence)		0.8941			0.9594		-0.0653
#       Positive(1) results metrics
#          Precision			0.7778			0.2621		0.5157
#          Recall				0.4118			0.4402		-0.0284
#          f1-score(confidence)		0.5385			0.3286		0.2099
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 3) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7894			0.7604		0.0290
#       Negative(0) results metrics
#          Precision			0.9268			0.9937		-0.0669
#          Recall				0.6441			0.6069		0.0371
#          f1-score(confidence)		0.7600			0.7536		0.0064
#       Positive(1) results metrics
#          Precision			0.6719			0.0937		0.5782
#          Recall				0.9348			0.9139		0.0209
#          f1-score(confidence)		0.7818			0.1700		0.6118
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8277
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7230			0.7460		0.0231
#       Negative(0) results metrics
#          Precision			0.7895			0.9809		-0.1914
#          Recall				0.8824			0.8749		0.0075
#          f1-score(confidence)		0.8333			0.9249		-0.0915
#       Positive(1) results metrics
#          Precision			0.7209			0.1799		0.5410
#          Recall				0.5636			0.6172		-0.0536
#          f1-score(confidence)		0.6327			0.2786		0.3540
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8357
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6935			0.6852		0.0083
#       Negative(0) results metrics
#          Precision			0.8389			0.9736		-0.1347
#          Recall				0.9557			0.9494		0.0063
#          f1-score(confidence)		0.8935			0.9613		-0.0678
#       Positive(1) results metrics
#          Precision			0.7586			0.2699		0.4887
#          Recall				0.4314			0.4211		0.0103
#          f1-score(confidence)		0.5500			0.3290		0.2210
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8355			0.7637		0.0717
#       Negative(0) results metrics
#          Precision			0.9020			0.9892		-0.0872
#          Recall				0.7797			0.6997		0.0799
#          f1-score(confidence)		0.8364			0.8196		0.0167
#       Positive(1) results metrics
#          Precision			0.7593			0.1092		0.6500
#          Recall				0.8913			0.8278		0.0636
#          f1-score(confidence)		0.8200			0.1930		0.6270
#
#    One to Two (627 items) : Model Score: 0.7872
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7545			0.7437		0.0108
#       Negative(0) results metrics
#          Precision			0.8165			0.9816		-0.1651
#          Recall				0.8725			0.8415		0.0311
#          f1-score(confidence)		0.8436			0.9062		-0.0626
#       Positive(1) results metrics
#          Precision			0.7292			0.1534		0.5758
#          Recall				0.6364			0.6459		-0.0096
#          f1-score(confidence)		0.6796			0.2479		0.4317
#
#    One to Three (836 items) : Model Score: 0.7927
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7071			0.6977		0.0094
#       Negative(0) results metrics
#          Precision			0.8488			0.9756		-0.1268
#          Recall				0.9241			0.9025		0.0215
#          f1-score(confidence)		0.8848			0.9377		-0.0528
#       Positive(1) results metrics
#          Precision			0.6757			0.1836		0.4921
#          Recall				0.4902			0.4928		-0.0026
#          f1-score(confidence)		0.5682			0.2675		0.3006
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 4) : Model Score: 0.7987
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8064			0.7806		0.0258
#       Negative(0) results metrics
#          Precision			0.9302			0.9941		-0.0639
#          Recall				0.6780			0.6474		0.0306
#          f1-score(confidence)		0.7843			0.7841		0.0002
#       Positive(1) results metrics
#          Precision			0.6935			0.1034		0.5902
#          Recall				0.9348			0.9139		0.0209
#          f1-score(confidence)		0.7963			0.1857		0.6106
#
#    One to Two (627 items, depth of 5) : Model Score: 0.8596
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7272			0.7580		0.0308
#       Negative(0) results metrics
#          Precision			0.7946			0.9824		-0.1877
#          Recall				0.8725			0.8653		0.0073
#          f1-score(confidence)		0.8318			0.9201		-0.0883
#       Positive(1) results metrics
#          Precision			0.7111			0.1769		0.5343
#          Recall				0.5818			0.6507		-0.0689
#          f1-score(confidence)		0.6400			0.2781		0.3619
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8421
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7068			0.7061		0.0007
#       Negative(0) results metrics
#          Precision			0.8466			0.9758		-0.1292
#          Recall				0.9430			0.9338		0.0092
#          f1-score(confidence)		0.8922			0.9543		-0.0621
#       Positive(1) results metrics
#          Precision			0.7273			0.2433		0.4840
#          Recall				0.4706			0.4785		-0.0079
#          f1-score(confidence)		0.5714			0.3226		0.2488
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.8179
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7931			0.7691		0.0240
#       Negative(0) results metrics
#          Precision			0.8913			0.9920		-0.1007
#          Recall				0.6949			0.6578		0.0371
#          f1-score(confidence)		0.7810			0.7910		-0.0101
#       Positive(1) results metrics
#          Precision			0.6949			0.1027		0.5922
#          Recall				0.8913			0.8804		0.0109
#          f1-score(confidence)		0.7810			0.1839		0.5970
#
#    One to Two (627 items) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6901			0.7496		0.0595
#       Negative(0) results metrics
#          Precision			0.7699			0.9823		-0.2124
#          Recall				0.8529			0.8389		0.0140
#          f1-score(confidence)		0.8093			0.9050		-0.0957
#       Positive(1) results metrics
#          Precision			0.6591			0.1542		0.5049
#          Recall				0.5273			0.6603		-0.1330
#          f1-score(confidence)		0.5859			0.2500		0.3359
#
#    One to Three (836 items) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6284			0.6624		0.0341
#       Negative(0) results metrics
#          Precision			0.8098			0.9718		-0.1621
#          Recall				0.9430			0.9325		0.0105
#          f1-score(confidence)		0.8713			0.9518		-0.0804
#       Positive(1) results metrics
#          Precision			0.6400			0.2055		0.4345
#          Recall				0.3137			0.3923		-0.0786
#          f1-score(confidence)		0.4211			0.2697		0.1513
#
# ******************************

# %% [markdown]
# ### MinMaxScaler

# %%
mms=MinMaxScaler()
mms_scaled=mms.fit_transform(df)
mms_df=pd.DataFrame(mms_scaled, columns=df.columns)
mms_df
# Out:
#            age  hypertension  heart_disease  ever_married  work_type  \
# 0     0.816895           0.0            1.0           1.0       0.50
# 1     0.975586           0.0            1.0           1.0       0.50
# 2     0.597168           0.0            0.0           1.0       0.50
# 3     0.963379           1.0            0.0           1.0       0.75
# 4     0.987793           0.0            0.0           1.0       0.50
# ...        ...           ...            ...           ...        ...
# 4903  0.157715           0.0            0.0           0.0       1.00
# 4904  0.987793           0.0            0.0           1.0       0.75
# 4905  0.426270           0.0            0.0           1.0       0.75
# 4906  0.621582           0.0            0.0           1.0       0.50
# 4907  0.536133           0.0            0.0           1.0       0.00
#
#       avg_glucose_level       bmi  smoking_status  Male  Urban  stroke
# 0              0.801265  0.301260        0.333333   1.0    1.0     1.0
# 1              0.234512  0.254296        0.666667   1.0    0.0     1.0
# 2              0.536008  0.276060        1.000000   0.0    1.0     1.0
# 3              0.549349  0.156930        0.666667   0.0    0.0     1.0
# 4              0.605161  0.214204        0.333333   1.0    1.0     1.0
# ...                 ...       ...             ...   ...    ...     ...
# 4903           0.221402  0.095074        0.000000   0.0    0.0     0.0
# 4904           0.323516  0.340206        0.666667   0.0    1.0     0.0
# 4905           0.128658  0.232532        0.666667   0.0    0.0     0.0
# 4906           0.513203  0.175258        0.333333   1.0    0.0     0.0
# 4907           0.139230  0.182131        0.000000   0.0    1.0     0.0
#
# [4908 rows x 11 columns]

# %%
for i in range(1,11):Test_Results(mms_df,'MinMaxScaler')
# Out:
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7894			0.7496		0.0398
#       Negative(0) results metrics
#          Precision			0.9268			0.9954		-0.0686
#          Recall				0.6441			0.5567		0.0874
#          f1-score(confidence)		0.7600			0.7141		0.0459
#       Positive(1) results metrics
#          Precision			0.6719			0.0864		0.5855
#          Recall				0.9348			0.9426		-0.0078
#          f1-score(confidence)		0.7818			0.1583		0.6235
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8298
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7405			0.7530		0.0125
#       Negative(0) results metrics
#          Precision			0.8073			0.9819		-0.1745
#          Recall				0.8627			0.8649		-0.0021
#          f1-score(confidence)		0.8341			0.9197		-0.0855
#       Positive(1) results metrics
#          Precision			0.7083			0.1743		0.5341
#          Recall				0.6182			0.6411		-0.0230
#          f1-score(confidence)		0.6602			0.2740		0.3862
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8389
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6739			0.6871		0.0131
#       Negative(0) results metrics
#          Precision			0.8297			0.9738		-0.1441
#          Recall				0.9557			0.9483		0.0074
#          f1-score(confidence)		0.8882			0.9609		-0.0726
#       Positive(1) results metrics
#          Precision			0.7407			0.2681		0.4727
#          Recall				0.3922			0.4258		-0.0337
#          f1-score(confidence)		0.5128			0.3290		0.1838
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 4) : Model Score: 0.8051
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7801		0.0324
#       Negative(0) results metrics
#          Precision			0.9130			0.9936		-0.0805
#          Recall				0.7119			0.6559		0.0560
#          f1-score(confidence)		0.8000			0.7902		0.0098
#       Positive(1) results metrics
#          Precision			0.7119			0.1047		0.6072
#          Recall				0.9130			0.9043		0.0087
#          f1-score(confidence)		0.8000			0.1876		0.6124
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8277
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7321			0.7454		0.0133
#       Negative(0) results metrics
#          Precision			0.7965			0.9808		-0.1843
#          Recall				0.8824			0.8783		0.0041
#          f1-score(confidence)		0.8372			0.9267		-0.0895
#       Positive(1) results metrics
#          Precision			0.7273			0.1829		0.5444
#          Recall				0.5818			0.6124		-0.0306
#          f1-score(confidence)		0.6465			0.2816		0.3648
#
#    One to Three (836 items, depth of 5) : Model Score: 0.8676
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7166			0.7296		0.0130
#       Negative(0) results metrics
#          Precision			0.8514			0.9780		-0.1266
#          Recall				0.9430			0.9281		0.0150
#          f1-score(confidence)		0.8949			0.9524		-0.0575
#       Positive(1) results metrics
#          Precision			0.7353			0.2472		0.4881
#          Recall				0.4902			0.5311		-0.0409
#          f1-score(confidence)		0.5882			0.3374		0.2508
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7572
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7894			0.7484		0.0410
#       Negative(0) results metrics
#          Precision			0.9268			0.9944		-0.0676
#          Recall				0.6441			0.5686		0.0754
#          f1-score(confidence)		0.7600			0.7235		0.0365
#       Positive(1) results metrics
#          Precision			0.6719			0.0873		0.5845
#          Recall				0.9348			0.9282		0.0066
#          f1-score(confidence)		0.7818			0.1597		0.6221
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8277
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7181			0.7446		0.0265
#       Negative(0) results metrics
#          Precision			0.7876			0.9806		-0.1930
#          Recall				0.8725			0.8815		-0.0089
#          f1-score(confidence)		0.8279			0.9284		-0.1005
#       Positive(1) results metrics
#          Precision			0.7045			0.1857		0.5189
#          Recall				0.5636			0.6077		-0.0440
#          f1-score(confidence)		0.6263			0.2844		0.3418
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8421
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6837			0.6890		0.0053
#       Negative(0) results metrics
#          Precision			0.8343			0.9740		-0.1397
#          Recall				0.9557			0.9474		0.0083
#          f1-score(confidence)		0.8909			0.9605		-0.0697
#       Positive(1) results metrics
#          Precision			0.7500			0.2671		0.4829
#          Recall				0.4118			0.4306		-0.0189
#          f1-score(confidence)		0.5316			0.3297		0.2020
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 4) : Model Score: 0.8019
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8040			0.7731		0.0309
#       Negative(0) results metrics
#          Precision			0.9111			0.9940		-0.0829
#          Recall				0.6949			0.6323		0.0627
#          f1-score(confidence)		0.7885			0.7729		0.0156
#       Positive(1) results metrics
#          Precision			0.7000			0.0995		0.6005
#          Recall				0.9130			0.9139		-0.0008
#          f1-score(confidence)		0.7925			0.1795		0.6129
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8191
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7475		0.0105
#       Negative(0) results metrics
#          Precision			0.7982			0.9810		-0.1827
#          Recall				0.8922			0.8778		0.0143
#          f1-score(confidence)		0.8426			0.9265		-0.0840
#       Positive(1) results metrics
#          Precision			0.7442			0.1835		0.5607
#          Recall				0.5818			0.6172		-0.0354
#          f1-score(confidence)		0.6531			0.2829		0.3702
#
#    One to Three (836 items, depth of 5) : Model Score: 0.8708
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7103			0.7319		0.0216
#       Negative(0) results metrics
#          Precision			0.8497			0.9783		-0.1286
#          Recall				0.9304			0.9232		0.0072
#          f1-score(confidence)		0.8882			0.9500		-0.0617
#       Positive(1) results metrics
#          Precision			0.6944			0.2384		0.4560
#          Recall				0.4902			0.5407		-0.0505
#          f1-score(confidence)		0.5747			0.3309		0.2438
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8064			0.7641		0.0423
#       Negative(0) results metrics
#          Precision			0.9302			0.9941		-0.0639
#          Recall				0.6780			0.6095		0.0685
#          f1-score(confidence)		0.7843			0.7557		0.0286
#       Positive(1) results metrics
#          Precision			0.6935			0.0947		0.5988
#          Recall				0.9348			0.9187		0.0161
#          f1-score(confidence)		0.7963			0.1717		0.6246
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8362
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7181			0.7469		0.0288
#       Negative(0) results metrics
#          Precision			0.7876			0.9809		-0.1933
#          Recall				0.8725			0.8766		-0.0040
#          f1-score(confidence)		0.8279			0.9258		-0.0979
#       Positive(1) results metrics
#          Precision			0.7045			0.1819		0.5226
#          Recall				0.5636			0.6172		-0.0536
#          f1-score(confidence)		0.6263			0.2810		0.3452
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8325
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6610			0.6843		0.0233
#       Negative(0) results metrics
#          Precision			0.8242			0.9736		-0.1495
#          Recall				0.9494			0.9428		0.0066
#          f1-score(confidence)		0.8824			0.9579		-0.0756
#       Positive(1) results metrics
#          Precision			0.7037			0.2486		0.4551
#          Recall				0.3725			0.4258		-0.0533
#          f1-score(confidence)		0.4872			0.3139		0.1732
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 3) : Model Score: 0.7859
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7894			0.7631		0.0263
#       Negative(0) results metrics
#          Precision			0.9268			0.9947		-0.0679
#          Recall				0.6441			0.5980		0.0461
#          f1-score(confidence)		0.7600			0.7469		0.0131
#       Positive(1) results metrics
#          Precision			0.6719			0.0931		0.5787
#          Recall				0.9348			0.9282		0.0066
#          f1-score(confidence)		0.7818			0.1693		0.6125
#
#    One to Two (627 items, depth of 3) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6866			0.7239		0.0373
#       Negative(0) results metrics
#          Precision			0.7627			0.9784		-0.2157
#          Recall				0.8824			0.8881		-0.0057
#          f1-score(confidence)		0.8182			0.9311		-0.1129
#       Positive(1) results metrics
#          Precision			0.6923			0.1820		0.5103
#          Recall				0.4909			0.5598		-0.0689
#          f1-score(confidence)		0.5745			0.2746		0.2998
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8405
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6904			0.6941		0.0038
#       Negative(0) results metrics
#          Precision			0.8380			0.9746		-0.1366
#          Recall				0.9494			0.9385		0.0109
#          f1-score(confidence)		0.8902			0.9562		-0.0660
#       Positive(1) results metrics
#          Precision			0.7333			0.2454		0.4879
#          Recall				0.4314			0.4498		-0.0184
#          f1-score(confidence)		0.5432			0.3176		0.2256
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 3) : Model Score: 0.7796
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7979			0.7598		0.0381
#       Negative(0) results metrics
#          Precision			0.9286			0.9940		-0.0654
#          Recall				0.6610			0.6010		0.0600
#          f1-score(confidence)		0.7723			0.7491		0.0232
#       Positive(1) results metrics
#          Precision			0.6825			0.0929		0.5897
#          Recall				0.9348			0.9187		0.0161
#          f1-score(confidence)		0.7890			0.1687		0.6203
#
#    One to Two (627 items, depth of 3) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7279			0.7461		0.0182
#       Negative(0) results metrics
#          Precision			0.7913			0.9810		-0.1897
#          Recall				0.8922			0.8702		0.0220
#          f1-score(confidence)		0.8387			0.9223		-0.0836
#       Positive(1) results metrics
#          Precision			0.7381			0.1757		0.5624
#          Recall				0.5636			0.6220		-0.0584
#          f1-score(confidence)		0.6392			0.2740		0.3652
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8405
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6739			0.6842		0.0103
#       Negative(0) results metrics
#          Precision			0.8297			0.9737		-0.1440
#          Recall				0.9557			0.9379		0.0178
#          f1-score(confidence)		0.8882			0.9554		-0.0672
#       Positive(1) results metrics
#          Precision			0.7407			0.2356		0.5051
#          Recall				0.3922			0.4306		-0.0385
#          f1-score(confidence)		0.5128			0.3046		0.2083
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7668
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7725			0.7502		0.0222
#       Negative(0) results metrics
#          Precision			0.9231			0.9945		-0.0714
#          Recall				0.6102			0.5722		0.0379
#          f1-score(confidence)		0.7347			0.7265		0.0082
#       Positive(1) results metrics
#          Precision			0.6515			0.0880		0.5635
#          Recall				0.9348			0.9282		0.0066
#          f1-score(confidence)		0.7679			0.1608		0.6071
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8234
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7272			0.7414		0.0142
#       Negative(0) results metrics
#          Precision			0.7946			0.9806		-0.1859
#          Recall				0.8725			0.8704		0.0022
#          f1-score(confidence)		0.8318			0.9222		-0.0904
#       Positive(1) results metrics
#          Precision			0.7111			0.1737		0.5374
#          Recall				0.5818			0.6124		-0.0306
#          f1-score(confidence)		0.6400			0.2706		0.3694
#
#    One to Three (836 items, depth of 4) : Model Score: 0.8357
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6546			0.6846		0.0300
#       Negative(0) results metrics
#          Precision			0.8222			0.9738		-0.1516
#          Recall				0.9367			0.9338		0.0029
#          f1-score(confidence)		0.8757			0.9534		-0.0777
#       Positive(1) results metrics
#          Precision			0.6552			0.2264		0.4288
#          Recall				0.3725			0.4354		-0.0629
#          f1-score(confidence)		0.4750			0.2979		0.1771
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7604
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7979			0.7550		0.0429
#       Negative(0) results metrics
#          Precision			0.9286			0.9939		-0.0653
#          Recall				0.6610			0.5914		0.0696
#          f1-score(confidence)		0.7723			0.7416		0.0307
#       Positive(1) results metrics
#          Precision			0.6825			0.0909		0.5916
#          Recall				0.9348			0.9187		0.0161
#          f1-score(confidence)		0.7890			0.1654		0.6235
#
#    One to Two (627 items, depth of 4) : Model Score: 0.8277
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7363			0.7511		0.0149
#       Negative(0) results metrics
#          Precision			0.8018			0.9817		-0.1799
#          Recall				0.8725			0.8659		0.0066
#          f1-score(confidence)		0.8357			0.9202		-0.0845
#       Positive(1) results metrics
#          Precision			0.7174			0.1743		0.5431
#          Recall				0.6000			0.6364		-0.0364
#          f1-score(confidence)		0.6535			0.2737		0.3798
#
#    One to Three (836 items, depth of 5) : Model Score: 0.8692
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7002			0.7284		0.0282
#       Negative(0) results metrics
#          Precision			0.8427			0.9779		-0.1352
#          Recall				0.9494			0.9304		0.0190
#          f1-score(confidence)		0.8929			0.9535		-0.0607
#       Positive(1) results metrics
#          Precision			0.7419			0.2517		0.4902
#          Recall				0.4510			0.5263		-0.0753
#          f1-score(confidence)		0.5610			0.3406		0.2204
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************
# Logistic Regression
#    One to One (418 items) : Model Score: 0.7700
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8379			0.7663		0.0715
#       Negative(0) results metrics
#          Precision			0.9184			0.9899		-0.0716
#          Recall				0.7627			0.6906		0.0721
#          f1-score(confidence)		0.8333			0.8136		0.0197
#       Positive(1) results metrics
#          Precision			0.7500			0.1080		0.6420
#          Recall				0.9130			0.8421		0.0709
#          f1-score(confidence)		0.8235			0.1914		0.6321
#
#    One to Two (627 items) : Model Score: 0.7894
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7370			0.7409		0.0039
#       Negative(0) results metrics
#          Precision			0.7982			0.9808		-0.1826
#          Recall				0.8922			0.8598		0.0324
#          f1-score(confidence)		0.8426			0.9163		-0.0737
#       Positive(1) results metrics
#          Precision			0.7442			0.1648		0.5794
#          Recall				0.5818			0.6220		-0.0402
#          f1-score(confidence)		0.6531			0.2605		0.3925
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6771			0.6661		0.0110
#       Negative(0) results metrics
#          Precision			0.8306			0.9722		-0.1416
#          Recall				0.9620			0.9302		0.0318
#          f1-score(confidence)		0.8915			0.9507		-0.0592
#       Positive(1) results metrics
#          Precision			0.7692			0.2039		0.5653
#          Recall				0.3922			0.4019		-0.0098
#          f1-score(confidence)		0.5195			0.2705		0.2489
#
# ******************************
# Random Forest Clasifier
#    One to One (418 items, depth of 2) : Model Score: 0.7636
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7979			0.7509		0.0470
#       Negative(0) results metrics
#          Precision			0.9286			0.9945		-0.0659
#          Recall				0.6610			0.5735		0.0875
#          f1-score(confidence)		0.7723			0.7275		0.0448
#       Positive(1) results metrics
#          Precision			0.6825			0.0883		0.5943
#          Recall				0.9348			0.9282		0.0066
#          f1-score(confidence)		0.7890			0.1612		0.6278
#
#    One to Two (627 items, depth of 3) : Model Score: 0.8170
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6957			0.7296		0.0339
#       Negative(0) results metrics
#          Precision			0.7692			0.9790		-0.2098
#          Recall				0.8824			0.8851		-0.0027
#          f1-score(confidence)		0.8219			0.9297		-0.1078
#       Positive(1) results metrics
#          Precision			0.7000			0.1818		0.5182
#          Recall				0.5091			0.5742		-0.0651
#          f1-score(confidence)		0.5895			0.2762		0.3133
#
#    One to Three (836 items, depth of 3) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.6183			0.6169		0.0014
#       Negative(0) results metrics
#          Precision			0.8042			0.9673		-0.1631
#          Recall				0.9620			0.9706		-0.0086
#          f1-score(confidence)		0.8761			0.9690		-0.0929
#       Positive(1) results metrics
#          Precision			0.7000			0.2850		0.4150
#          Recall				0.2745			0.2632		0.0114
#          f1-score(confidence)		0.3944			0.2736		0.1207
#
# ******************************
# SVC
#    One to One (418 items) : Model Score: 0.7732
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.8125			0.7579		0.0546
#       Negative(0) results metrics
#          Precision			0.9130			0.9909		-0.0779
#          Recall				0.7119			0.6497		0.0622
#          f1-score(confidence)		0.8000			0.7848		0.0152
#       Positive(1) results metrics
#          Precision			0.7119			0.0991		0.6128
#          Recall				0.9130			0.8660		0.0470
#          f1-score(confidence)		0.8000			0.1778		0.6222
#
#    One to Two (627 items) : Model Score: 0.8149
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.7041			0.7381		0.0340
#       Negative(0) results metrics
#          Precision			0.7788			0.9811		-0.2023
#          Recall				0.8627			0.8398		0.0230
#          f1-score(confidence)		0.8186			0.9049		-0.0863
#       Positive(1) results metrics
#          Precision			0.6818			0.1501		0.5317
#          Recall				0.5455			0.6364		-0.0909
#          f1-score(confidence)		0.6061			0.2429		0.3631
#
#    One to Three (836 items) : Model Score: 0.7943
# 					Test Data	Available Data		Difference
#       Balanced Accuracy:		0.5661			0.6063		0.0402
#       Negative(0) results metrics
#          Precision			0.7824			0.9666		-0.1842
#          Recall				0.9557			0.9542		0.0015
#          f1-score(confidence)		0.8604			0.9604		-0.1000
#       Positive(1) results metrics
#          Precision			0.5625			0.2007		0.3618
#          Recall				0.1765			0.2584		-0.0819
#          f1-score(confidence)		0.2687			0.2259		0.0427
#
# ******************************

# %%
results_df=pd.read_csv('fidel-test-results-LabelEncoded.csv')
results_df
# Out:
#                   Test_Model    Proportion     Compression  Model_Score  \
# 0        Logistic Regression    One to One  StandardScaler     0.766773
# 1        Logistic Regression    One to Two  StandardScaler     0.787234
# 2        Logistic Regression  One to Three  StandardScaler     0.792663
# 3    Random Forest Clasifier    One to One  StandardScaler     0.757188
# 4    Random Forest Clasifier    One to Two  StandardScaler     0.821277
# ..                       ...           ...             ...          ...
# 175  Random Forest Clasifier    One to Two    MinMaxScaler     0.817021
# 176  Random Forest Clasifier  One to Three    MinMaxScaler     0.794258
# 177                      SVC    One to One    MinMaxScaler     0.773163
# 178                      SVC    One to Two    MinMaxScaler     0.814894
# 179                      SVC  One to Three    MinMaxScaler     0.794258
#
#      Balanced Accuracy  Precision    Recall  f1-score
# 0             0.763737   0.109217  0.827751  0.192973
# 1             0.743694   0.153409  0.645933  0.247934
# 2             0.697678   0.183601  0.492823  0.267532
# 3             0.745932   0.086898  0.923445  0.158848
# 4             0.748328   0.172324  0.631579  0.270769
# ..                 ...        ...       ...       ...
# 175           0.729622   0.181818  0.574163  0.276180
# 176           0.616895   0.284974  0.263158  0.273632
# 177           0.757871   0.099070  0.866029  0.177800
# 178           0.738058   0.150113  0.636364  0.242922
# 179           0.606309   0.200743  0.258373  0.225941
#
# [180 rows x 8 columns]

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Test_Model         180 non-null    object
#  1   Proportion         180 non-null    object
#  2   Compression        180 non-null    object
#  3   Model_Score        180 non-null    float64
#  4   Balanced Accuracy  180 non-null    float64
#  5   Precision          180 non-null    float64
#  6   Recall             180 non-null    float64
#  7   f1-score           180 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 11.4+ KB

# %%
results_df.sort_values('f1-score',ascending=False)
# Out:
#                   Test_Model    Proportion     Compression  Model_Score  \
# 59   Random Forest Clasifier  One to Three  StandardScaler     0.899522
# 167  Random Forest Clasifier  One to Three    MinMaxScaler     0.869219
# 104  Random Forest Clasifier  One to Three    MinMaxScaler     0.867624
# 122  Random Forest Clasifier  One to Three    MinMaxScaler     0.870813
# 14   Random Forest Clasifier  One to Three  StandardScaler     0.837321
# ..                       ...           ...             ...          ...
# 3    Random Forest Clasifier    One to One  StandardScaler     0.757188
# 30   Random Forest Clasifier    One to One  StandardScaler     0.757188
# 93   Random Forest Clasifier    One to One    MinMaxScaler     0.766773
# 12   Random Forest Clasifier    One to One  StandardScaler     0.760383
# 39   Random Forest Clasifier    One to One  StandardScaler     0.757188
#
#      Balanced Accuracy  Precision    Recall  f1-score       Encoder
# 59            0.757974   0.265086  0.588517  0.365527  LabelEncoder
# 167           0.728363   0.251716  0.526316  0.340557  LabelEncoder
# 104           0.729585   0.247216  0.531100  0.337386  LabelEncoder
# 122           0.731923   0.238397  0.540670  0.330893  LabelEncoder
# 14            0.694610   0.261972  0.444976  0.329787  LabelEncoder
# ..                 ...        ...       ...       ...           ...
# 3             0.745932   0.086898  0.923445  0.158848  LabelEncoder
# 30            0.744391   0.086799  0.918660  0.158612  LabelEncoder
# 93            0.749649   0.086404  0.942584  0.158297  LabelEncoder
# 12            0.745022   0.085217  0.937799  0.156238  LabelEncoder
# 39            0.744490   0.085033  0.937799  0.155927  LabelEncoder
#
# [180 rows x 9 columns]

# %%
results_df['Encoder']='LabelEncoder'

# %%
results_df.to_csv('fidel-test-results.csv', mode='w',index=False )

# %%
import os
os.getcwd()
# Out:
# 'g:\\My Drive\\SMU AI\\Projects\\Stroke_Prediction-'
